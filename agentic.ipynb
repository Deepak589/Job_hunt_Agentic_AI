# %%
import langchain_anthropic
import dotenv
from langchain_anthropic import ChatAnthropic
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


dotenv.load_dotenv()


prompt_template = ChatPromptTemplate.from_template("explain about {topic}")
model = ChatAnthropic(model_name="claude-haiku-4-5-20251001")
parser = StrOutputParser()

chain = prompt_template | model | parser
result = chain.invoke({"topic": "RAG"})
print(result)
# Out:
# # RAG (Retrieval-Augmented Generation)
#
# RAG is a technique that combines **information retrieval** with **generative AI** to produce more accurate and contextual responses.
#
# ## How It Works
#
# ```
# User Question
#      ↓
# [1. RETRIEVAL] → Search knowledge base/documents
#      ↓
# [2. AUGMENTATION] → Combine retrieved info with prompt
#      ↓
# [3. GENERATION] → LLM generates answer using context
#      ↓
# Response with Sources
# ```
#
# ## Key Components
#
# | Component | Purpose |
# |-----------|---------|
# | **Retriever** | Searches and finds relevant documents |
# | **Knowledge Base** | Repository of documents/data |
# | **LLM** | Generates response based on context |
#
# ## Why Use RAG?
#
# ✅ **Reduces hallucinations** - uses real data instead of training data only
# ✅ **Current information** - accesses up-to-date documents
# ✅ **Explainability** - shows source documents
# ✅ **Domain-specific** - works with custom knowledge
# ✅ **Cost-effective** - smaller models can perform well
#
# ## Example Use Cases
#
# - **Customer support** - retrieve relevant docs, answer questions
# - **Legal research** - search contracts, provide analysis
# - **Medical AI** - cite research papers in responses
# - **Enterprise chatbots** - access internal knowledge bases
#
# ## RAG vs. Fine-tuning
#
# | RAG | Fine-tuning |
# |-----|------------|
# | Dynamic (updates without retraining) | Static (must retrain) |
# | Uses external data | Modifies model weights |
# | Faster to implement | More expensive |
#
# **Simple takeaway:** RAG lets AI systems consult documents before answering, making them more reliable and current.
